# %%
import pandas as pd

# %%
data = pd.read_csv(r'C:\Users\rosar\RufoEsEterno\universidad202601\TF-TP_DataVisualization\Data\2025-Gasto-OPDS.csv')

# %%
data.head(20)
# Out:
#     ANO_EJE  MES_EJE  GRUPO_ENTIDAD  \
# 0      2025        2             14
# 1      2025        7             14
# 2      2025        3             14
# 3      2025        2             14
# 4      2025        9             14
# 5      2025       10             14
# 6      2025        0             14
# 7      2025        0             14
# 8      2025       10             14
# 9      2025        8             14
# 10     2025        8             14
# 11     2025       12             14
# 12     2025        1             14
# 13     2025       12             14
# 14     2025        6             14
# 15     2025        5             14
# 16     2025       12             14
# 17     2025        0             14
# 18     2025        6             14
# 19     2025       10             14
#
#                                 GRUPO_ENTIDAD_NOMBRE  SEC_EJEC  EJECUTORA  \
# 0   ORGANISMOS PUBLICOS DESCENTRALIZADOS MUNICIPALES    500319          0
# ...

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 65698 entries, 0 to 65697
# Data columns (total 58 columns):
#  #   Column                         Non-Null Count  Dtype
# ---  ------                         --------------  -----
#  0   ANO_EJE                        65698 non-null  int64
#  1   MES_EJE                        65698 non-null  int64
#  2   GRUPO_ENTIDAD                  65698 non-null  int64
#  3   GRUPO_ENTIDAD_NOMBRE           65698 non-null  object
#  4   SEC_EJEC                       65698 non-null  int64
#  5   EJECUTORA                      65698 non-null  int64
#  6   EJECUTORA_NOMBRE               65698 non-null  object
#  7   DEPARTAMENTO_EJECUTORA         65698 non-null  int64
#  8   DEPARTAMENTO_EJECUTORA_NOMBRE  65698 non-null  object
#  9   PROVINCIA_EJECUTORA            65698 non-null  int64
#  10  PROVINCIA_EJECUTORA_NOMBRE     65698 non-null  object
#  11  DISTRITO_EJECUTORA             65698 non-null  int64
# ...

# %%
data.sample(10)
# Out:
#        ANO_EJE  MES_EJE  GRUPO_ENTIDAD  \
# 26340     2025        5             14
# 41517     2025       10             14
# 50570     2025        3             14
# 3076      2025        4             14
# 32804     2025       12             14
# 29002     2025        7             14
# 29565     2025        0             14
# 38016     2025        8             14
# 346       2025        7             14
# 31162     2025        0             14
#
#                                    GRUPO_ENTIDAD_NOMBRE  SEC_EJEC  EJECUTORA  \
# 26340  ORGANISMOS PUBLICOS DESCENTRALIZADOS MUNICIPALES    500235          0
# 41517  ORGANISMOS PUBLICOS DESCENTRALIZADOS MUNICIPALES    500256          0
# 50570  ORGANISMOS PUBLICOS DESCENTRALIZADOS MUNICIPALES    500256          0
# 3076   ORGANISMOS PUBLICOS DESCENTRALIZADOS MUNICIPALES    500319          0
# 32804  ORGANISMOS PUBLICOS DESCENTRALIZADOS MUNICIPALES    500232          0
# ...

# %%
data["ESPECIFICA_NOMBRE"].value_counts(dropna=False)
# Out:
# ESPECIFICA_NOMBRE
# OBLIGACIONES DEL EMPLEADOR                              6016
# CONTRATO ADMINISTRATIVO DE SERVICIOS                    5692
# OTROS SERVICIOS                                         4899
# LOCACIÓN DE SERVICIOS REALIZADOS POR PERSONA NATURAL    3773
# VIAJES DOMESTICOS                                       3365
#                                                         ...
# TRANSFERENCIAS CORRIENTES                                  4
# INDEMNIZACIONES Y COMPENSACIONES                           4
# FORMACION Y CAPACITACION                                   4
# INFRAESTRUCTURA ELECTRICA                                  3
# ADQUISICION DE BIENES AGROPECUARIOS, MINEROS Y OTROS       2
# Name: count, Length: 96, dtype: int64

# %%
data["EJECUTORA_NOMBRE"].unique()
# Out:
# array(['ESTABLECIMIENTO DE SALUD MUNICIPAL - ESAMU',
#        'INSTITUTO MUNICIPAL DE PLANEAMIENTO DE AREQUIPA',
#        'SERVICIO MUNICIPAL DE ADMINISTRACIÓN DEL MATADERO METROPOLITANO DE RÍO SECO',
#        'ZONA ESPECIAL DE DESARROLLO MATARANI - ZED MATARANI',
#        'SERVICIO DE ADMINISTRACIÓN TRIBUTARIA DE HUAMANGA - AYNI MUNICIPAL',
#        'TERRAPUERTO MUNICIPAL LIBERTADORES DE AMERICA',
#        'SERVICIO DE ADMINISTRACIÓN TRIBUTARIA DE CAJAMARCA',
#        'SERVICIO DE ADMINISTRACIÓN TRIBUTARIA DE ICA',
#        'SERVICIO DE ADMINISTRACION TRIBUTARIA DE HUANCAYO',
#        'TRANSPORTES METROPOLITANOS DE TRUJILLO',
#        'SERVICIO DE GESTIÓN AMBIENTAL DE TRUJILLO',
#        'SERVICIO DE ADMINISTRACIÓN DE INMUEBLES MUNICIPALES DE TRUJILLO',
#        'SERVICIO DE ADMINISTRACION TRIBUTARIA DE TRUJILLO',
#        'SERVICIO DE ADMINISTRACIÓN TRIBUTARIA DE CHICLAYO - SATCH',
#        'SERVICIO DE ADMINISTRACIÓN TRIBUTARIA DE JOSÉ LEONARDO ORTIZ',
# ...
