# %%
pip install gdown
# Out:
# ...
# Note: you may need to restart the kernel to use updated packages.
# WARNING: You are using pip version 21.2.3; however, version 26.1 is available.
# You should consider upgrading via the 'c:\Users\User\AppData\Local\Programs\Python\Python310\python.exe -m pip install --upgrade pip' command.

# %%
import gdown
import pandas as pd

url = "https://drive.google.com/file/d/1bwod-g4qw30pXyFBdaYnRanAJd1_LoqY/view?usp=sharing"
gdown.download(url, "Gasto_OPDS_2018_2026.csv", quiet=False)

df = pd.read_csv("Gasto_OPDS_2018_2026.csv")
# Out:
# Downloading...
# From (original): https://drive.google.com/uc?id=1bwod-g4qw30pXyFBdaYnRanAJd1_LoqY
# From (redirected): https://drive.google.com/uc?id=1bwod-g4qw30pXyFBdaYnRanAJd1_LoqY&confirm=t&uuid=478a85cd-e271-443f-a98a-cbc5b3bfbd97
# To: c:\Users\User\OneDrive\Documents\GitHub\TF-TP_DataVisualization\Code\Gasto_OPDS_2018_2026.csv
# 100%|██████████| 324M/324M [00:11<00:00, 28.9MB/s]
# C:\Users\User\AppData\Local\Temp\ipykernel_24172\3727855316.py:7: DtypeWarning: Columns (36) have mixed types. Specify dtype option on import or set low_memory=False.
#   df = pd.read_csv("Gasto_OPDS_2018_2026.csv")

# %%
df.head()
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 458756 entries, 0 to 458755
# Data columns (total 59 columns):
#  #   Column                         Non-Null Count   Dtype
# ---  ------                         --------------   -----
#  0   ANO_EJE                        458756 non-null  int64
#  1   MES_EJE                        458756 non-null  int64
#  2   GRUPO_ENTIDAD                  458756 non-null  int64
#  3   GRUPO_ENTIDAD_NOMBRE           458756 non-null  object
#  4   SEC_EJEC                       458756 non-null  int64
#  5   EJECUTORA                      458756 non-null  int64
#  6   EJECUTORA_NOMBRE               458756 non-null  object
#  7   DEPARTAMENTO_EJECUTORA         458756 non-null  int64
#  8   DEPARTAMENTO_EJECUTORA_NOMBRE  458756 non-null  object
#  9   PROVINCIA_EJECUTORA            458756 non-null  int64
#  10  PROVINCIA_EJECUTORA_NOMBRE     458756 non-null  object
#  11  DISTRITO_EJECUTORA             458756 non-null  int64
# ...
